# %% [markdown]
# # Introduction
#
# Today we'll dive deep into a dataset all about LEGO. From the dataset we can ask whole bunch of interesting questions about the history of the LEGO company, their product offering, and which LEGO set ultimately rules them all:
#
# <ul type="square">
# <li>What is the most enormous LEGO set ever created and how many parts did it have?</li>
#
# <li>How did the LEGO company start out? In which year were the first LEGO sets released and how many sets did the company sell when it first launched?</li>
#
# <li>Which LEGO theme has the most sets? Is it one of LEGO's own themes like Ninjago or a theme they licensed liked Harry Potter or Marvel Superheroes?</li>
#
# <li>When did the LEGO company really expand its product offering? Can we spot a change in the company strategy based on how many themes and sets did it released year-on-year?</li>
#
# <li>Did LEGO sets grow in size and complexity over time? Do older LEGO
# sets tend to have more or fewer parts than newer sets?</li>
# </ul>
#
# **Data Source**
#
# [Rebrickable](https://rebrickable.com/downloads/) has compiled data on all the LEGO pieces in existence. I recommend you use download the .csv files provided in this lesson.

# %% [markdown]
# ## 612 Use HTML Markdown to Make Your Notebook Look Pretty

# %% [markdown]
# <h2>This is a sample text.</h2>

# %% [markdown]
# <img src='https://images.unsplash.com/photo-1518773553398-650c184e0bb3?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D'></img>

# %% [markdown]
# # Import Statements

# %%
import pandas

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Exploration

# %% [markdown]
# **Challenge**: How many different colours does the LEGO company produce? Read the colors.csv file in the data folder and find the total number of unique colours. Try using the [.nunique() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html?highlight=nunique#pandas.DataFrame.nunique) to accomplish this.

# %%
colors_data = pandas.read_csv('./data/colors.csv')

# %%
colors_data
# Out:
#        id                          name     rgb is_trans
# 0      -1                       Unknown  0033B2        f
# 1       0                         Black  05131D        f
# 2       1                          Blue  0055BF        f
# 3       2                         Green  237841        f
# 4       3                Dark Turquoise  008F9B        f
# ..    ...                           ...     ...      ...
# 130  1004  Trans Flame Yellowish Orange  FCB76D        t
# 131  1005             Trans Fire Yellow  FBE890        t
# 132  1006        Trans Light Royal Blue  B4D4F7        t
# 133  1007                 Reddish Lilac  8E5597        f
# 134  9999                    [No Color]  05131D        f
#
# [135 rows x 4 columns]

# %%
colors_data.shape
# Out:
# (135, 4)

# %%
colors_data.isna()
# Out:
#         id   name    rgb  is_trans
# 0    False  False  False     False
# 1    False  False  False     False
# 2    False  False  False     False
# 3    False  False  False     False
# 4    False  False  False     False
# ..     ...    ...    ...       ...
# 130  False  False  False     False
# 131  False  False  False     False
# 132  False  False  False     False
# 133  False  False  False     False
# 134  False  False  False     False
#
# [135 rows x 4 columns]

# %%
colors_data['rgb'].unique()
# Out:
# array(['0033B2', '05131D', '0055BF', '237841', '008F9B', 'C91A09',
#        'C870A0', '583927', '9BA19D', '6D6E5C', 'B4D2E3', '4B9F4A',
#        '55A5AF', 'F2705E', 'FC97AC', 'F2CD37', 'FFFFFF', 'C2DAB8',
#        'FBE696', 'E4CD9E', 'C9CAE2', 'D4D5C9', '81007B', '2032B0',
#        'FE8A18', '923978', 'BBE90B', '958A73', 'E4ADC8', 'AC78BA',
#        'E1D5ED', '635F52', '0020A0', '84B68D', 'D9E4A7', 'AEEFEC',
#        'F8F184', 'C1DFF0', 'DF6695', 'F5CD2F', 'FCFCFC', 'A5A5CB',
#        'DAB000', 'FF800D', '645A4C', '6C96BF', '3CB371', 'AA4D8E',
#        '1B2A34', 'F3CF9B', 'CD6298', '582A12', 'A0A5A9', '6C6E68',
#        '5A93DB', '73DCA1', '000000', '635F61', 'FECCCF', 'F6D7B3',
#        'A5A9B4', '899B5F', 'DBAC34', 'CC702A', '3F3691', '7C503A',
#        '4C61DB', 'D09168', 'FEBABD', '4354A3', '6874CA', 'C7D23C',
#        'B3D7D1', 'F9BA61', 'AE7A59', '9CA3A8', '7988A1', 'DCBC81',
#        'CFE2F7', '575857', 'ABADAC', 'E6E3E0', 'DFEEA5', 'B48455',
# ...

# %%
len(colors_data['rgb'].unique())
# Out:
# 124

# %%
colors_data[colors_data['rgb'] == '000000']
# Out:
#      id                  name     rgb is_trans
# 58   75  Speckle Black-Copper  000000        f
# 81  132  Speckle Black-Silver  000000        f
# 82  133    Speckle Black-Gold  000000        f

# %%
len(colors_data[colors_data['rgb'] == '000000'])
# Out:
# 3

# %%
colors_data.groupby('rgb').count()
# Out:
#         id  name  is_trans
# rgb
# 000000   3     3         3
# 0020A0   1     1         1
# 0033B2   1     1         1
# 0055BF   1     1         1
# 008F9B   1     1         1
# ...     ..   ...       ...
# FECCCF   1     1         1
# FF800D   1     1         1
# FFA70B   1     1         1
# FFF03A   1     1         1
# FFFFFF   3     3         3
#
# [124 rows x 3 columns]

# %% [markdown]
# There's a number of different ways you can accomplish this. Maybe try using the `.nunique()` from Pandas this time.

# %%
colors_data.nunique(axis='columns', dropna=True)
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
#       ..
# 130    4
# 131    4
# 132    4
# 133    4
# 134    4
# Length: 135, dtype: int64

# %% [markdown]
# When we put `axis='columns'`, it finds all the unique values in every row, and as we can see from the df, every row contains 4 unique values, so the code generates an output of 4 for every row, for all 135 rows.
#
# **To find the unique values for every column, we need to put `axis='index'`**

# %%
colors_data.nunique(axis='index', dropna=True)
# Out:
# id          135
# name        135
# rgb         124
# is_trans      2
# dtype: int64

# %% [markdown]
# **Challenge**: Find the number of transparent colours where <code>is_trans == 't'</code> versus the number of opaque colours where <code>is_trans == 'f'</code>. See if you can accomplish this in two different ways.

# %% [markdown]
# **This below can be method 1**

# %%
colors_data.groupby('is_trans').count()
# Out:
#            id  name  rgb
# is_trans
# f         107   107  107
# t          28    28   28

# %%
colors_data.groupby('is_trans').sum()
# Out:
#              id                                               name  \
# is_trans
# f         27058  UnknownBlackBlueGreenDark TurquoiseRedDark Pin...
# t          7102  Trans-Black IR LensTrans-Dark BlueTrans-GreenT...
#
#                                                         rgb
# is_trans
# f         0033B205131D0055BF237841008F9BC91A09C870A05839...
# t         635F520020A084B68DD9E4A7C91A09635F52AEEFECF8F1...

# %% [markdown]
# **This can be method 2**

# %%
colors_data[colors_data['is_trans'] == 'f']
# Out:
#        id                name     rgb is_trans
# 0      -1             Unknown  0033B2        f
# 1       0               Black  05131D        f
# 2       1                Blue  0055BF        f
# 3       2               Green  237841        f
# 4       3      Dark Turquoise  008F9B        f
# ..    ...                 ...     ...      ...
# 125   503     Very Light Gray  E6E3DA        f
# 126  1000  Glow in Dark White  D9D9D9        f
# 127  1001       Medium Violet  9391E4        f
# 133  1007       Reddish Lilac  8E5597        f
# 134  9999          [No Color]  05131D        f
#
# [107 rows x 4 columns]

# %%
len(colors_data[colors_data['is_trans'] == 'f'])
# Out:
# 107

# %%
colors_data['is_trans'].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
for i in colors_data['is_trans'].unique():
  color_count = len(colors_data[colors_data['is_trans'] == f'{i}'])
  print(f'The number of {i} is {color_count}')
# Out:
# The number of f is 107
# The number of t is 28

# %% [markdown]
# **Bonus Method**

# %%
colors_data['is_trans'].value_counts()
# Out:
# is_trans
# f    107
# t     28
# Name: count, dtype: int64

# %% [markdown]
# **Challenge**: Change this into an h3 section heading: Understanding LEGO Themes vs. LEGO Sets

# %% [markdown]
# <h3>Understanding LEGO Themes vs. LEGO Sets</h3>

# %% [markdown]
# Walk into a LEGO store and you will see their products organised by theme. Their themes include Star Wars, Batman, Harry Potter and many more.
#
# **Challenge**: Display this image: https://i.imgur.com/aKcwkSx.png

# %% [markdown]
# <img src="https://i.imgur.com/aKcwkSx.png">

# %% [markdown]
# A lego set is a particular box of LEGO or product. Therefore, a single theme typically has many different sets.
#
# **Challenge**: Display this image https://i.imgur.com/whB1olq.png

# %% [markdown]
# <img src="https://i.imgur.com/whB1olq.png">

# %% [markdown]
# ## 614 Find the Oldest and Largest LEGO Sets

# %% [markdown]
# The <code>sets.csv</code> data contains a list of sets over the years and the number of parts that each of these sets contained.
#
# **Challenge**: Read the sets.csv data and take a look at the first and last couple of rows.

# %%
sets_data = pandas.read_csv("./data/sets.csv")

# %%
sets_data.head(n=5)
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0   001-1                       Gears  1965         1         43
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %% [markdown]
# **Challenge**: In which year were the first LEGO sets released and what were these sets called?

# %%
sets_data['year']
# Out:
# 0        1965
# 1        1978
# 2        1987
# 3        1979
# 4        1979
#          ...
# 15705    1996
# 15706    2019
# 15707    2019
# 15708    2019
# 15709    2013
# Name: year, Length: 15710, dtype: int64

# %%
sets_data['year'].min()
# Out:
# 1949

# %% [markdown]
# This means that the first set was released in the year 1949.

# %%
sets_data['year'].idxmin()
# Out:
# 9521

# %% [markdown]
# And it is in the id 9521

# %%
sets_data[sets_data['year']== 1949]
# Out:
#       set_num                               name  year  theme_id  num_parts
# 9521  700.1-1         Extra-Large Gift Set (ABB)  1949       365        142
# 9534  700.2-1               Large Gift Set (ABB)  1949       365        178
# 9539  700.3-1              Medium Gift Set (ABB)  1949       365        142
# 9544  700.A-1              Small Brick Set (ABB)  1949       371         24
# 9545  700.B-1  Small Doors and Windows Set (ABB)  1949       371         12

# %%
sets_data['year'].loc[9521]
# Out:
# 1949

# %%
sets_data.loc[9521]
# Out:
# set_num                         700.1-1
# name         Extra-Large Gift Set (ABB)
# year                               1949
# theme_id                            365
# num_parts                           142
# Name: 9521, dtype: object

# %% [markdown]
# **Challenge**: How many different sets did LEGO sell in their first year? How many types of LEGO products were on offer in the year the company started?

# %%
len(sets_data[sets_data['year'] == sets_data['year'].min()])
# Out:
# 5

# %% [markdown]
# Five sets

# %%
data_for_the_year_lego_started = sets_data[sets_data['year'] == sets_data['year'].min()]

# %%
data_for_the_year_lego_started['theme_id'].unique()
# Out:
# array([365, 371])

# %%
len(data_for_the_year_lego_started['theme_id'].unique())
# Out:
# 2

# %% [markdown]
# Two Types

# %% [markdown]
# **Challenge**: Find the top 5 LEGO sets with the most number of parts.

# %%
sets_data.sort_values('num_parts', ascending=False)
# Out:
#          set_num                                              name  year  \
# 15004   BIGBOX-1                     The Ultimate Battle for Chima  2015
# 11183    75192-1                             UCS Millennium Falcon  2017
# 10551    71043-1                                   Hogwarts Castle  2018
# 295      10256-1                                         Taj Mahal  2017
# 221      10189-1                                         Taj Mahal  2008
# ...          ...                                               ...   ...
# 1782     20216-1  MBA Robot & Micro Designer (Kits 2 - 3 Redesign)  2013
# 1780     20214-1      MBA Adventure Designer (Kits 7 - 9 Redesign)  2013
# 6822   5005539-1                              Brick Pouch (Yellow)  2018
# 9026     66319-1                     Power Miners 3 in 1 Superpack  2009
# 12946   853471-1                                   C-3PO Key Chain  2015
#
#        theme_id  num_parts
# 15004       571       9987
# 11183       171       7541
# ...

# %%
sets_data.sort_values('num_parts', ascending=False).head(n=5)
# Out:
#         set_num                           name  year  theme_id  num_parts
# 15004  BIGBOX-1  The Ultimate Battle for Chima  2015       571       9987
# 11183   75192-1          UCS Millennium Falcon  2017       171       7541
# 10551   71043-1                Hogwarts Castle  2018       246       6020
# 295     10256-1                      Taj Mahal  2017       673       5923
# 221     10189-1                      Taj Mahal  2008       673       5922

# %% [markdown]
# ## 615 Visualise the Number of Sets Published over Time

# %% [markdown]
# **Challenge**: Use <code>.groupby()</code> and <code>.count()</code> to show the number of LEGO sets released year-on-year. How do the number of sets released in 1955 compare to the number of sets released in 2019?

# %%
sets_data.groupby('year').count()
# Out:
#       set_num  name  theme_id  num_parts
# year
# 1949        5     5         5          5
# 1950        6     6         6          6
# 1953        4     4         4          4
# 1954       14    14        14         14
# 1955       28    28        28         28
# ...       ...   ...       ...        ...
# 2017      786   786       786        786
# 2018      816   816       816        816
# 2019      840   840       840        840
# 2020      674   674       674        674
# 2021        3     3         3          3
#
# [71 rows x 4 columns]

# %%
data_grouped_by_year = sets_data.groupby('year').count()

# %%
data_grouped_by_year.loc[[1949, 2019]]
# Out:
#       set_num  name  theme_id  num_parts
# year
# 1949        5     5         5          5
# 2019      840   840       840        840

# %% [markdown]
# **Challenge**: Show the number of LEGO releases on a line chart using Matplotlib. <br>

# %%
data_grouped_by_year['name']
# Out:
# year
# 1949      5
# 1950      6
# 1953      4
# 1954     14
# 1955     28
#        ...
# 2017    786
# 2018    816
# 2019    840
# 2020    674
# 2021      3
# Name: name, Length: 71, dtype: int64

# %% [markdown]
# The count in year 1949 is 5. This means that 5 releases were made in that year.

# %%
plt.plot(data_grouped_by_year['name'])

# %% [markdown]
# Note that the .csv file is from late 2020, so to plot the full calendar years, you will have to exclude some data from your chart. Can you use the slicing techniques covered in Day 21 to avoid plotting the last two years? The same syntax will work on Pandas DataFrames.

# %%
plt.plot(data_grouped_by_year['name'][:-2])

# %% [markdown]
# ## 616 How to use the Pandas .agg() function

# %% [markdown]
# Often you find yourself needing to summarise data. This is where the .groupby() function comes in really handy. However, sometimes you want to run even more operations based on a particular DataFrame column. This is where the .agg() method comes in.

# %% [markdown]
# In our case, we want to calculate the number of different themes by calendar year. This means we have to group the data by year and then count the number of unique theme_ids for that year.

# %% [markdown]
# We can accomplish this by chaining the .groupby() and the .agg() functions together

# %% [markdown]
# ### Aggregate Data with the Python .agg() Function
#
# Let's work out the number of different themes shipped by year. This means we have to count the number of unique theme_ids per calendar year.

# %%
sets_data
# Out:
#            set_num                                 name  year  theme_id  \
# 0            001-1                                Gears  1965         1
# 1           0011-2                    Town Mini-Figures  1978        84
# 2           0011-3           Castle 2 for 1 Bonus Offer  1987       199
# 3           0012-1                   Space Mini-Figures  1979       143
# 4           0013-1                   Space Mini-Figures  1979       143
# ...            ...                                  ...   ...       ...
# 15705      wwgp1-1  Wild West Limited Edition Gift Pack  1996       476
# 15706   XMASTREE-1                       Christmas Tree  2019       410
# 15707      XWING-1                  Mini X-Wing Fighter  2019       158
# 15708      XWING-2                    X-Wing Trench Run  2019       158
# 15709  YODACHRON-1      Yoda Chronicles Promotional Set  2013       158
#
#        num_parts
# 0             43
# 1             12
# 2              0
# 3             12
# ...

# %%
sets_data.groupby('year').agg({'theme_id':pandas.Series.nunique})
# Out:
#       theme_id
# year
# 1949         2
# 1950         1
# 1953         2
# 1954         2
# 1955         4
# ...        ...
# 2017        89
# 2018        93
# 2019        78
# 2020        82
# 2021         1
#
# [71 rows x 1 columns]

# %% [markdown]
# We can add further functions to get aggregated data on other columns too. For example, let's say I want to find how many unique names of sets there are for each year.

# %%
sets_data.groupby('year').agg({'theme_id':pandas.Series.nunique, 'name':pandas.Series.nunique})
# Out:
#       theme_id  name
# year
# 1949         2     5
# 1950         1     6
# 1953         2     4
# 1954         2    13
# 1955         4    27
# ...        ...   ...
# 2017        89   760
# 2018        93   799
# 2019        78   825
# 2020        82   664
# 2021         1     3
#
# [71 rows x 2 columns]

# %% [markdown]
# The name 'theme_id' for this column is a little misleading. After all, it represents the number of different themes.

# %%
themes_by_year = sets_data.groupby('year').agg({'theme_id':pandas.Series.nunique})

# %%
themes_by_year.columns = ['nr_themes']

# %%
themes_by_year
# Out:
#       nr_themes
# year
# 1949          2
# 1950          1
# 1953          2
# 1954          2
# 1955          4
# ...         ...
# 2017         89
# 2018         93
# 2019         78
# 2020         82
# 2021          1
#
# [71 rows x 1 columns]

# %% [markdown]
# We could rename the columns another way too.

# %%
themes_by_year.rename(columns = {'theme_id':'nr_themes'}, inplace=True)

# %%
themes_by_year
# Out:
#       nr_themes
# year
# 1949          2
# 1950          1
# 1953          2
# 1954          2
# 1955          4
# ...         ...
# 2017         89
# 2018         93
# 2019         78
# 2020         82
# 2021          1
#
# [71 rows x 1 columns]

# %% [markdown]
# **Challenge**: Plot the number of themes released by year on a line chart. Only include the full calendar years (i.e., exclude 2020 and 2021).

# %%
plt.plot(themes_by_year[:-2])

# %% [markdown]
# We can do it another way, by mentioning the x-axis and the y-axis separately.

# %%
plt.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2])

# %% [markdown]
# ## 617 Superimposing Line Charts with Separate Axes

# %% [markdown]
# Wouldn't it be nice to have the number of themes and the number sets on the same chart? But what do we get if we just plot both of them the way we have before?

# %%
plt.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2])

# %% [markdown]
# First, we need a dataset with both the themes and the sets as columns

# %%
year_themes_sets = sets_data.groupby('year').agg({'theme_id':pandas.Series.nunique, 'set_num':pandas.Series.nunique})

# %%
year_themes_sets
# Out:
#       theme_id  set_num
# year
# 1949         2        5
# 1950         1        6
# 1953         2        4
# 1954         2       14
# 1955         4       28
# ...        ...      ...
# 2017        89      786
# 2018        93      816
# 2019        78      840
# 2020        82      674
# 2021         1        3
#
# [71 rows x 2 columns]

# %%
plt.plot(year_themes_sets.index[:-2], year_themes_sets.theme_id[:-2], year_themes_sets.set_num[:-2])

# %% [markdown]
# Alternative way

# %%
plt.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2])

# %%
plt.plot(data_grouped_by_year.index[:-2], data_grouped_by_year.set_num[:-2])

# %%
plt.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2])
plt.plot(data_grouped_by_year.index[:-2], data_grouped_by_year.set_num[:-2])

# %% [markdown]
# Well, that's not very informative! 🤦‍♀️ The problem is that the "number of themes" and the "number of sets" have very different scales. The theme number ranges between 0 and 90, while the number of sets ranges between 0 and 900. So what can we do?

# %% [markdown]
# ### Line Charts with Two Seperate Axes

# %% [markdown]
# We need to be able to configure and plot our data on two separate axes on the same chart. This involves getting hold of an axis object from Matplotlib.

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same x-axis

# %% [markdown]
# We then create another axis object: ax2. The key thing is that by using the .twinx() method allows ax1 and ax2 to share the same x-axis. When we plot our data on the axes objects we get this:

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same x-axis

ax1.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2])
ax2.plot(data_grouped_by_year.index[:-2], data_grouped_by_year.set_num[:-2])

# %% [markdown]
# That's very nice! But there's one problem: we can't tell the lines apart because they have the same colour! Let's add some styling. Let's:
#
# *   colour in the lines
# *   colour in the axes and
# *   add some labels
#
# so that we can see what's going on. Here's what we get:

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same x-axis

ax1.set_xlabel('Year', fontsize=10)
ax1.set_ylabel('Number of Themes', fontsize=10, color='blue')
ax2.set_ylabel('Number of Sets', fontsize=10, color='green')

ax1.plot(themes_by_year.index[:-2], themes_by_year.nr_themes[:-2], color='b')
ax2.plot(data_grouped_by_year.index[:-2], data_grouped_by_year.set_num[:-2], color='g')

# %% [markdown]
# ## 618 Scatter Plots_ Average Number of Parts per LEGO Set

# %% [markdown]
# **Complexity Over Time**
#
# Have LEGO sets become larger and more complex over time? Let's work out the average number of parts per LEGO set. This is the perfect time to revise how to use the .agg() function.

# %%
sets_data
# Out:
#            set_num                                 name  year  theme_id  \
# 0            001-1                                Gears  1965         1
# 1           0011-2                    Town Mini-Figures  1978        84
# 2           0011-3           Castle 2 for 1 Bonus Offer  1987       199
# 3           0012-1                   Space Mini-Figures  1979       143
# 4           0013-1                   Space Mini-Figures  1979       143
# ...            ...                                  ...   ...       ...
# 15705      wwgp1-1  Wild West Limited Edition Gift Pack  1996       476
# 15706   XMASTREE-1                       Christmas Tree  2019       410
# 15707      XWING-1                  Mini X-Wing Fighter  2019       158
# 15708      XWING-2                    X-Wing Trench Run  2019       158
# 15709  YODACHRON-1      Yoda Chronicles Promotional Set  2013       158
#
#        num_parts
# 0             43
# 1             12
# 2              0
# 3             12
# ...

# %%
sets_data[sets_data['year'] == 1949]
# Out:
#       set_num                               name  year  theme_id  num_parts
# 9521  700.1-1         Extra-Large Gift Set (ABB)  1949       365        142
# 9534  700.2-1               Large Gift Set (ABB)  1949       365        178
# 9539  700.3-1              Medium Gift Set (ABB)  1949       365        142
# 9544  700.A-1              Small Brick Set (ABB)  1949       371         24
# 9545  700.B-1  Small Doors and Windows Set (ABB)  1949       371         12

# %%
yearly_data = sets_data.groupby('year')

# %%
yearly_data.agg({'num_parts':pandas.Series.mean})
# Out:
#        num_parts
# year
# 1949   99.600000
# 1950    1.000000
# 1953   13.500000
# 1954   12.357143
# 1955   36.607143
# ...          ...
# 2017  221.840967
# 2018  213.618873
# 2019  207.510714
# 2020  259.732938
# 2021    0.000000
#
# [71 rows x 1 columns]

# %% [markdown]
# To double check, the column above shows that in 1949 on average each set contained 99.6 parts. Manually checking from `sets_data` -

# %%
(142+178+142+24+12)/5
# Out:
# 99.6

# %% [markdown]
# **Challenge**: Use the <code>.groupby()</code> and <code>.agg()</code> function together to figure out the average number of parts per set. How many parts did the average LEGO set released in 1954 compared to say, 2017?

# %%
# Putting it all together

sets_data.groupby('year').agg({'num_parts':pandas.Series.mean})
# Out:
#        num_parts
# year
# 1949   99.600000
# 1950    1.000000
# 1953   13.500000
# 1954   12.357143
# 1955   36.607143
# ...          ...
# 2017  221.840967
# 2018  213.618873
# 2019  207.510714
# 2020  259.732938
# 2021    0.000000
#
# [71 rows x 1 columns]

# %% [markdown]
# **Challenge**
#
#
# Create a Pandas Series called `parts_per_set` that has the year as the index and contains the average number of parts per LEGO set in that year.

# %%
parts_per_set = sets_data.groupby('year').agg({'num_parts':pandas.Series.mean})

# %%
parts_per_set.rename(columns = {'num_parts':'average_num_parts'}, inplace=True)

# %%
parts_per_set.head()
# Out:
#       average_num_parts
# year
# 1949          99.600000
# 1950           1.000000
# 1953          13.500000
# 1954          12.357143
# 1955          36.607143

# %%
parts_per_set.tail()
# Out:
#       average_num_parts
# year
# 2017         221.840967
# 2018         213.618873
# 2019         207.510714
# 2020         259.732938
# 2021           0.000000

# %% [markdown]
# ### Scatter Plots in Matplotlib

# %% [markdown]
# **Challenge**: Has the size and complexity of LEGO sets increased over time based on the number of parts? Plot the average number of parts over time using a Matplotlib scatter plot. See if you can use the [scatter plot documentation](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.scatter.html) before I show you the solution. Do you spot a trend in the chart?

# %% [markdown]
# To visualise our `parts_per_set` data, let's create a scatter plot. A scatter plot simply uses dots to represent the values of each data point.

# %% [markdown]
# See if you can use the Matplotlib documentation to generate the scatter plot chart. Do you spot a trend in the chart? Again, you'll have to exclude the last two observations.

# %%
plt.scatter(x=parts_per_set.index[:-2], y=parts_per_set.average_num_parts[:-2])

# %% [markdown]
# From the chart, we can definitely make out an upward trend in the size and complexity of the LEGO sets based on the average number of parts. In the 2010s the average set contained around 200 individual pieces, which is roughly double what average LEGO set used to contain in the 1960s.

# %% [markdown]
# ## 619 Relational Database Schemas_ Primary and Foreign Keys

# %% [markdown]
# ### Number of Sets per LEGO Theme

# %% [markdown]
# LEGO has licensed many hit franchises from Harry Potter to Marvel Super Heros to many others. But which theme has the largest number of individual sets?

# %%
sets_data.head(n=5)
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0   001-1                       Gears  1965         1         43
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
sets_data.groupby('theme_id').count()
# Out:
#           set_num  name  year  num_parts
# theme_id
# 1             167   167   167        167
# 2               4     4     4          4
# 3              18    18    18         18
# 4              39    39    39         39
# 5              12    12    12         12
# ...           ...   ...   ...        ...
# 705             8     8     8          8
# 706            52    52    52         52
# 707             2     2     2          2
# 708            43    43    43         43
# 709             4     4     4          4
#
# [571 rows x 4 columns]

# %%
sets_data.groupby('theme_id').agg({'set_num':pandas.Series.nunique}).sort_values('set_num', ascending=False)
# Out:
#           set_num
# theme_id
# 158           753
# 501           656
# 494           398
# 435           356
# 503           329
# ...           ...
# 212             1
# 210             1
# 200             1
# 509             1
# 368             1
#
# [571 rows x 1 columns]

# %% [markdown]
# We can also do it like this -

# %%
sets_data['theme_id'].value_counts().head(n=5)
# Out:
# theme_id
# 158    753
# 501    656
# 494    398
# 435    356
# 503    329
# Name: count, dtype: int64

# %% [markdown]
# **But**
#
# We have no idea what our themes are actually called! 🤨 Ok, we can see that the theme with id 158 is the largest theme containing 753 individual sets, but what's that theme called? This is not very helpful. We need to find the names of the themes based on the theme_id from the themes.csv file.

# %% [markdown]
# **Challenge** Use what you know about HTML markup and tags to display the database schema: https://i.imgur.com/Sg4lcjx.png

# %% [markdown]
# <img src='https://img-c.udemycdn.com/redactor/raw/2020-10-10_10-18-49-1748f6889ed0e6b0565269b40f279453.png'>

# %% [markdown]
# **Working with a Relational Database**
#
# What is a database schema? A schema is just how the database is organised. Many relational databases, such as our LEGO data, is split into individual tables. We have separate tables for the colours, the sets and the thems. With a relational database, the tables are linked to each other through their keys.

# %% [markdown]
# ### Database Schemas, Foreign Keys and Merging DataFrames
#
# The themes.csv file has the actual theme names. The sets .csv has <code>theme_ids</code> which link to the <code>id</code> column in the themes.csv.

# %%
themes_data = pandas.read_csv('./data/themes.csv')

# %%
themes_data
# Out:
#       id                   name  parent_id
# 0      1                Technic        NaN
# 1      2         Arctic Technic        1.0
# 2      3            Competition        1.0
# 3      4         Expert Builder        1.0
# 4      5                  Model        1.0
# ..   ...                    ...        ...
# 591  705               Iron Man      696.0
# 592  706             Spider-Man      696.0
# 593  707                  X-Men      696.0
# 594  708  The LEGO Batman Movie      697.0
# 595  709               LEGO Art        NaN
#
# [596 rows x 3 columns]

# %% [markdown]
# **Challenge**: Explore the themes.csv. How is it structured? Search for the name 'Star Wars'. How many <code>id</code>s correspond to this name in the themes.csv? Now use these <code>id</code>s and find the corresponding sets in the sets.csv (Hint: you'll need to look for matches in the <code>theme_id</code> column)

# %%
themes_data.head(n=5)
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   2  Arctic Technic        1.0
# 2   3     Competition        1.0
# 3   4  Expert Builder        1.0
# 4   5           Model        1.0

# %%
themes_data[themes_data['name'] == 'Star Wars']
# Out:
#       id       name  parent_id
# 17    18  Star Wars        1.0
# 150  158  Star Wars        NaN
# 174  209  Star Wars      207.0
# 211  261  Star Wars      258.0

# %%
len(themes_data[themes_data['name'] == 'Star Wars'])
# Out:
# 4

# %%
themes_data[themes_data['name'] == 'Star Wars']['id']
# Out:
# 17      18
# 150    158
# 174    209
# 211    261
# Name: id, dtype: int64

# %%
for i in themes_data[themes_data['name'] == 'Star Wars']['id']:
  print(i)
# Out:
# 18
# 158
# 209
# 261

# %%
# this is how to fiter using the id
sets_data[sets_data['theme_id'] == 1]
# Out:
#       set_num                            name  year  theme_id  num_parts
# 0       001-1                           Gears  1965         1         43
# 8       002-1  4.5V Samsonite Gears Motor Set  1965         1          3
# 324    1030-1  TECHNIC I: Simple Machines Set  1985         1        191
# 331    1038-1              ERBIE the Robo-Car  1985         1        120
# 332    1039-1            Manual Control Set 1  1986         1         39
# ...       ...                             ...   ...       ...        ...
# 14969  9970-1                   Axles - Short  1994         1         36
# 14970  9971-1                    Axles - Long  1994         1         24
# 14971  9972-1                    Plates (Red)  1994         1         88
# 14972  9973-1                   Plates (Blue)  1994         1         88
# 14973  9974-1                 Plates (Yellow)  1994         1         88
#
# [167 rows x 5 columns]

# %%
# now implementing the for loop to the sets_data
for i in themes_data[themes_data['name'] == 'Star Wars']['id']:
  print(i)
  display(sets_data[sets_data['theme_id'] == i])
# Out:
# 18
#        set_num                                name  year  theme_id  num_parts
# 8786   65081-1  R2-D2 / C-3PO Droid Collectors Set  2002        18          1
# 12051   8000-1                           Pit Droid  2000        18        223
# 12058   8001-1                        Battle Droid  2000        18        336
# 12066   8002-1                     Destroyer Droid  2000        18        567
# 12071   8007-1                               C-3PO  2001        18        339
# 12072   8008-1                        Stormtrooper  2001        18        360
# 12073   8009-1                               R2-D2  2002        18        239
# 12074   8010-1                         Darth Vader  2002        18        388
# 12081   8011-1                          Jango Fett  2002        18        425
# 12083   8012-1                  Super Battle Droid  2002        18        378
# 15273  K8008-1      Darth Vader / Stormtrooper Kit  2002        18          0
# 158
# ...

# %% [markdown]
# Here we see that all of the Star Wars Advent Calendars share the same theme_id. That makes sense.

# %% [markdown]
# <img src='https://img-c.udemycdn.com/redactor/raw/2020-10-10_10-20-45-635c014ae055a295c7e605acb5cd3bc1.jpg'>

# %% [markdown]
# ## 620 How to Merge DataFrames and Create Bar Charts

# %% [markdown]
# Wouldn't it be nice if we could combine our data on theme names with the number sets per theme?

# %% [markdown]
# Let's use the `.merge()` method to combine two separate DataFrames into one. The merge method works on columns with the same name in both DataFrames.

# %% [markdown]
# Currently, our theme_ids and our number of sets per theme live inside a Series called set_theme_count.

# %% [markdown]
# A series is nothing but one column.

# %%
set_theme_count = sets_data['theme_id'].value_counts()

# %%
set_theme_count
# Out:
# theme_id
# 158    753
# 501    656
# 494    398
# 435    356
# 503    329
#       ...
# 307      1
# 215      1
# 361      1
# 210      1
# 414      1
# Name: count, Length: 571, dtype: int64

# %%
set_theme_count.sort_index(ascending=True)
# Out:
# theme_id
# 1      167
# 2        4
# 3       18
# 4       39
# 5       12
#       ...
# 705      8
# 706     52
# 707      2
# 708     43
# 709      4
# Name: count, Length: 571, dtype: int64

# %% [markdown]
# To make sure we have a column with the name id, I'll convert this Pandas Series into a Pandas DataFrame.

# %% [markdown]
# ### Merging (i.e., Combining) DataFrames based on a Key

# %% [markdown]
# In the `set_theme_count` series, the first column represents the theme id and the second the number of sets.

# %%
set_theme_count_df = pandas.DataFrame({
    'id': set_theme_count.index,
    'set_count':set_theme_count.values,
})

# %% [markdown]
# Here I'm providing a dictionary to create the DataFrame. The keys in the dictionary become my column names.

# %%
set_theme_count_df
# Out:
#       id  set_count
# 0    158        753
# 1    501        656
# 2    494        398
# 3    435        356
# 4    503        329
# ..   ...        ...
# 566  307          1
# 567  215          1
# 568  361          1
# 569  210          1
# 570  414          1
#
# [571 rows x 2 columns]

# %% [markdown]
# **The Pandas `.merge()` function**
#
# To `.merge()` two DataFrame along a particular column, we need to provide our two DataFrames and then the column name on which to merge. This is why we set on='id'. Both our set_theme_count and our themes DataFrames have a column with this name.

# %%
themes_data.head(n=5)
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   2  Arctic Technic        1.0
# 2   3     Competition        1.0
# 3   4  Expert Builder        1.0
# 4   5           Model        1.0

# %%
set_theme_count_df.head(n=5)
# Out:
#     id  set_count
# 0  158        753
# 1  501        656
# 2  494        398
# 3  435        356
# 4  503        329

# %% [markdown]
# Let's create the merged dataframe

# %%
merged_df = pandas.merge(set_theme_count_df, themes_data, on='id')

# %%
merged_df.head(n=5)
# Out:
#     id  set_count       name  parent_id
# 0  158        753  Star Wars        NaN
# 1  501        656       Gear        NaN
# 2  494        398    Friends        NaN
# 3  435        356    Ninjago        NaN
# 4  503        329  Key Chain      501.0

# %% [markdown]
# Aha! Star Wars is indeed the theme with the most LEGO sets.

# %% [markdown]
# #### Creating a Bar Chart

# %% [markdown]
# Let's plot the top 10 themes on a chart.

# %% [markdown]
# Matplotlib can create almost any chart imaginable with very few lines of code. Using `.bar()` we can provide our theme names and the number of sets.

# %%
plt.bar(x=merged_df.name[:10], height=merged_df.set_count[:10])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# That worked, but it's almost unreadable. 😩 The good thing for us is that we already know how to customize our charts! Here's what we get when we increase the size of our figure, add some labels, and most importantly, rotate the category names on the x-axis so that they don't overlap.

# %%
plt.figure(figsize=(14,8))
# The figure() function in pyplot module of matplotlib library is used to create a new figure.
# figsize(float, float): These parameter are the width, height in inches.
plt.xticks(fontsize=14, rotation=45) # rotation applied
plt.yticks(fontsize=14)
# name the axes
plt.ylabel('Nr of Sets', fontsize=14)
plt.xlabel('Theme Name', fontsize=14)
plt.bar(merged_df.name[:10], merged_df.set_count[:10])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Niiiiice.😌 So what can we see here? Well, a couple of these themes like Star Wars, Town, or Ninjago are what I would think of when I think of LEGO. However, it looks like LEGO also produces a huge number of ... books and key chains?!?! I guess I'm showing my age here, but it's interesting that the LEGO company seems to produce so much more these days than just plastic bricks. The 'Gear' category itself is huge and includes everything from bags to pencil cases apparently. Has LEGO strayed from its core business or is it successfully diversifying? That we can't answer from our dataset. I'll leave that one up to a business school case study to decide. 🤷‍♀️

# %% [markdown]
# #### fin
